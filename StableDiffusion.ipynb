# %%
# !pip install diffusers transformers torch accelerate
# !pip install huggingface_hub

# %%
from huggingface_hub import login
from diffusers import StableDiffusionPipeline
import torch

# %%
# Login to Hugging Face
login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Load the pre-trained Stable Diffusion model
model_id = "stabilityai/stable-diffusion-2-1-base"  # Use a different model if 3.0 is unavailable
pipe = StableDiffusionPipeline.from_pretrained(model_id)
# Out:
# model_index.json:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# text_encoder/config.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/807 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# unet/config.json:   0%|          | 0.00/911 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# ...

# %%
# Ensure the model uses the GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = pipe.to(device)

# %%
prompt = "Imagine celebrating next April amidst a sea of pink, picnicking under the cherry blossoms during Japan’s Hanami season"

# %%
# Generate the image
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# Save the image
image.save("generated_image.png")

# %%
# Display the image
image.show()
